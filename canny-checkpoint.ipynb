# %%
import cv2 as c
import numpy as n
import matplotlib.pyplot  as plt

# %%
img=c.imread("flower.jpg",0)
plt.imshow(img)

# %%
canny=c.Canny(img,70,100)
plt.imshow(canny)

# %%
vid=c.VideoCapture("dq.mp4")

# %%
while(1):
    ret,frame=vid.read()
    gray=c.cvtColor(frame,c.COLOR_BGR2RGB)
    
    edges=c.Canny(frame,80,200)
    c.imshow("eDGES",edges)
    if c.waitKey(5)& 0xFF==ord('j'):
        break
vid.release()
c.destroyAllWindows()
